# %%
from main import SnowBlaze

# %%
if __name__ == "__main__":
    # You can specify a database URL or let it default to SQLite
    # Example: db_url = "postgresql://user:password@localhost/snowblaze"
    import json
    zene_agent = SnowBlaze(user_id="user_01")
    
    # If this is a returning user, their conversation history is already loaded
    # response = zene_agent("Hello, can you say who is the author of amuktha malayalam?")
    response = zene_agent("Hello, can you explain the poem 'Amuktha Malayalam'")
    print(json.dumps(response, indent=2))
    
    # Conversation is automatically saved to database after each interaction
    # You can also manually save to file
# Out:
# 2025-03-22 09:54:59,307 - main - INFO - No existing zene conversation found for user user_01
# 2025-03-22 09:54:59,309 - main - INFO - No existing commet conversation found for user user_01
# 2025-03-22 09:54:59,310 - main - INFO - No existing finn conversation found for user user_01
# 2025-03-22 09:54:59,311 - main - INFO - No existing milo conversation found for user user_01
# 2025-03-22 09:54:59,312 - main - INFO - No existing thalia conversation found for user user_01
# 2025-03-22 09:54:59,312 - main - INFO - Processing message: Hello, can you explain the poem 'Amuktha Malayalam'
# 2025-03-22 09:55:00,983 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-22 09:55:00,993 - main - INFO - zene token usage: {'prompt_tokens': 1008, 'completion_tokens': 119, 'total_tokens': 1127, 'latency_seconds': 1.68003511428833}
# 2025-03-22 09:55:00,994 - main - INFO - zene latency: 1.68 seconds
# 2025-03-22 09:55:00,996 - main - INFO - Saved zene conversation for user user_01 to database
# 2025-03-22 09:55:10,674 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-22 09:55:10,677 - main - INFO - finn token usage: {'prompt_tokens': 428, 'completion_tokens': 789, 'total_tokens': 1217, 'latency_seconds': 9.67655897140503}
# 2025-03-22 09:55:10,678 - main - INFO - finn latency: 9.68 seconds
# 2025-03-22 09:55:10,680 - main - INFO - Saved finn conversation for user user_01 to database
# 2025-03-22 09:55:10,685 - main - INFO - Routing to Milo agent based on Zene response
# 2025-03-22 09:55:49,542 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-22 09:55:49,562 - main - INFO - milo token usage: {'prompt_tokens': 8417, 'completion_tokens': 1070, 'total_tokens': 9487, 'latency_seconds': 38.87432074546814}
# 2025-03-22 09:55:49,562 - main - INFO - milo latency: 38.87 seconds
# 2025-03-22 09:55:49,570 - main - INFO - Saved milo conversation for user user_01 to database
# {
#   "summary": "This teaching note provides a comprehensive explanation of the poem 'Amuktha Malayalam', focusing on its historical context, themes, and literary analysis. The notes are structured into distinct sections, each addressing a specific aspect of the poem, such as its background, themes, and impact on Malayalam literature. The content is organized hierarchically with clear numbering, key tags, and slide layout suggestions to facilitate effective learning and recall. Each section concludes with assessment points to test the understanding of the topic.",
#   "sections": [
#     {
#       "section_sequential_id": 1,
#       "title": "Historical Context and Background of 'Amuktha Malayalam'",
#       "content": [
#         {
#           "content_sequential_id": "1.1",
#           "text": "Amuktha Malayalam is a significant work in Malayalam literature, attributed to the medieval period.",
#           "tags": [
#             "Amuktha Malayalam",
#             "Malayalam literature",
#             "medieval period"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "1.2",
#           "text": "The poem is believed to have been composed during the 14th century, a time of rich literary activity in Kerala.",
#           "tags": [
#             "14th century",
#             "literary activity",
#             "Kerala"
#           ],
#           "references": [
#             {
#               "current_tag": "Amuktha Malayalam",
#               "other_content_sequential_id": "1.1",
#               "other_content_tags": [
#                 "Malayalam literature"
#               ]
#             }
#           ]
#         },
#         {
#           "content_sequential_id": "1.3",
#           "text": "The author of Amuktha Malayalam is not definitively known, but it is often associated with the works of Cherusseri Namboothiri, a prominent poet of the time.",
#           "tags": [
#             "Cherusseri Namboothiri",
#             "authorship",
#             "prominent poet"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "1.4",
#           "text": "The poem reflects the socio-cultural milieu of medieval Kerala, characterized by a blend of indigenous traditions and external influences.",
#           "tags": [
#             "socio-cultural milieu",
#             "indigenous traditions",
#             "external influences"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "1.5",
#           "text": "Amuktha Malayalam is part of the larger tradition of Manipravalam literature, which combines Malayalam and Sanskrit.",
#           "tags": [
#             "Manipravalam literature",
#             "Malayalam",
#             "Sanskrit"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "1.6",
#           "text": "The poem is an example of the Bhakti movement's influence on Malayalam literature, emphasizing devotion and spirituality.",
#           "tags": [
#             "Bhakti movement",
#             "devotion",
#             "spirituality"
#           ],
#           "references": []
#         }
#       ],
#       "slide_layout": "A title slide with a header, followed by bullet points summarizing the historical context, authorship, and cultural influences, with an accompanying timeline or map of Kerala during the medieval period.",
#       "assessment_questions": [
#         {
#           "question_sequential_id": "1.Q1",
#           "concept_to_be_assessed": "Understanding the historical context and cultural background of 'Amuktha Malayalam'."
#         }
#       ],
#       "content_checks": {
#         "accuracy_through_sources": [
#           "'A History of Malayalam Literature' by K. M. George",
#           "'Medieval Indian Literature: An Anthology' by Ayyappa Paniker"
#         ],
#         "missing_content": []
#       }
#     },
#     {
#       "section_sequential_id": 2,
#       "title": "Themes and Literary Analysis of 'Amuktha Malayalam'",
#       "content": [
#         {
#           "content_sequential_id": "2.1",
#           "text": "The central themes of Amuktha Malayalam include devotion, spirituality, and the human experience.",
#           "tags": [
#             "central themes",
#             "devotion",
#             "spirituality",
#             "human experience"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "2.2",
#           "text": "The poem employs a lyrical and narrative style, characteristic of Manipravalam literature.",
#           "tags": [
#             "lyrical style",
#             "narrative style",
#             "Manipravalam literature"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "2.3",
#           "text": "It uses rich imagery and metaphors to convey deep spiritual and philosophical ideas.",
#           "tags": [
#             "imagery",
#             "metaphors",
#             "spiritual ideas",
#             "philosophical ideas"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "2.4",
#           "text": "The poem reflects the Bhakti movement's influence, focusing on personal devotion to a deity.",
#           "tags": [
#             "Bhakti movement",
#             "personal devotion",
#             "deity"
#           ],
#           "references": [
#             {
#               "current_tag": "Bhakti movement",
#               "other_content_sequential_id": "1.6",
#               "other_content_tags": [
#                 "devotion",
#                 "spirituality"
#               ]
#             }
#           ]
#         },
#         {
#           "content_sequential_id": "2.5",
#           "text": "Amuktha Malayalam has had a lasting impact on Malayalam literature, inspiring subsequent generations of poets and writers.",
#           "tags": [
#             "impact",
#             "Malayalam literature",
#             "inspiration"
#           ],
#           "references": []
#         },
#         {
#           "content_sequential_id": "2.6",
#           "text": "The poem's blend of Malayalam and Sanskrit set a precedent for future literary works in the region.",
#           "tags": [
#             "blend",
#             "Malayalam",
#             "Sanskrit",
#             "literary precedent"
#           ],
#           "references": []
#         }
#       ],
#       "slide_layout": "A slide with a central theme cloud, surrounded by bullet points detailing the literary style, use of imagery, and impact on literature, with visual examples of Manipravalam script.",
#       "assessment_questions": [
#         {
#           "question_sequential_id": "2.Q1",
#           "concept_to_be_assessed": "Analyzing the themes and literary techniques used in 'Amuktha Malayalam'."
#         }
#       ],
#       "content_checks": {
#         "accuracy_through_sources": [
#           "'Manipravalam: A Study of the Early Malayalam Literature' by K. Ayyappa Paniker",
#           "'The Bhakti Movement: Renaissance or Revivalism?' by R. N. Dandekar"
#         ],
#         "missing_content": []
#       }
#     }
#   ]
# }

# %%
if __name__ == "__main__":
    # You can specify a database URL or let it default to SQLite
    # Example: db_url = "postgresql://user:password@localhost/snowblaze"
    import json
    zene_agent = SnowBlaze(user_id="raja01")
    
    # If this is a returning user, their conversation history is already loaded
    response = zene_agent("Hello, can you say who is the author of amuktha malayalam?")

    print(json.dumps(response, indent=2))
    
    # Conversation is automatically saved to database after each interaction
    # You can also manually save to file
# Out:
# 2025-03-22 09:55:55,843 - main - INFO - No existing zene conversation found for user raja01
# 2025-03-22 09:55:55,844 - main - INFO - No existing commet conversation found for user raja01
# 2025-03-22 09:55:55,846 - main - INFO - No existing finn conversation found for user raja01
# 2025-03-22 09:55:55,847 - main - INFO - No existing milo conversation found for user raja01
# 2025-03-22 09:55:55,848 - main - INFO - No existing thalia conversation found for user raja01
# 2025-03-22 09:55:55,849 - main - INFO - Processing message: Hello, can you say who is the author of amuktha malayalam?
